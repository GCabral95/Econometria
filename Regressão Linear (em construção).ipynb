# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm

# %% [markdown]
# ### Base
#
# * Indicadores de municípios brasileiros em diversos períodos

# %%
df = pd.read_csv('municipios.csv')

# %%
pd.set_option('display.max_columns', None)
df.head(5)
# Out:
#    id_municipio   ano  expectativa_vida  fecundidade_total  mortalidade_1  \
# 0       1100015  1991             62.01               4.08          45.58
# 1       1100015  2000             66.90               3.11          28.36
# 2       1100015  2010             70.75               2.24          23.80
# 3       1100023  1991             66.02               3.72          32.39
# 4       1100023  2000             69.52               2.77          21.68
#
#    mortalidade_5  razao_dependencia  prob_sobrevivencia_40  \
# 0          58.05              73.50                  83.81
# 1          33.96              61.65                  89.61
# 2          25.49              47.37                  94.50
# 3          41.41              69.97                  88.08
# 4          25.99              59.88                  91.91
#
#    prob_sobrevivencia_60  taxa_envelhecimento  expectativa_anos_estudo  \
# 0                  66.87                 1.82                     6.68
# 1                  75.40                 3.35                     7.76
# 2                  83.18                 5.84                     8.67
# 3                  74.23                 1.82                     7.86
# 4                  80.15                 2.92                     7.61
#
#    taxa_analfabetismo_11_a_14  taxa_analfabetismo_15_a_17  \
# 0                        9.74                        8.35
# 1                        2.32                        2.60
# 2                        1.22                        1.52
# 3                        9.35                        7.64
# 4                        2.64                        2.52
#
#    taxa_analfabetismo_15_mais  taxa_analfabetismo_18_a_24  \
# 0                       23.55                       10.82
# 1                       15.84                        4.11
# 2                       11.99                        1.68
# 3                       17.18                        8.00
# 4                       11.77                        3.57
#
#    taxa_analfabetismo_18_mais  taxa_analfabetismo_25_a_29  \
# 0                       25.71                       15.59
# 1                       17.42                        6.37
# 2                       13.00                        2.72
# 3                       18.37                       10.55
# 4                       12.81                        5.28
#
#    taxa_analfabetismo_25_mais  taxa_atraso_0_basico  \
# 0                       31.39                 30.32
# 1                       21.54                 49.82
# 2                       15.76                 57.62
# 3                       22.32                 37.37
# 4                       15.76                 52.48
#
#    taxa_atraso_0_fundamental  taxa_atraso_0_medio  taxa_atraso_1_basico  \
# 0                      33.34                53.26                 24.96
# 1                      54.43                62.62                 25.57
# 2                      63.21                66.39                 20.36
# 3                      40.76                45.41                 25.11
# 4                      58.38                54.89                 21.16
#
#    taxa_atraso_1_fundamental  taxa_atraso_1_medio  taxa_atraso_2_basico  \
# 0                      27.33                16.63                 44.72
# 1                      26.10                34.18                 24.62
# 2                      18.97                25.81                 22.03
# 3                      26.42                44.13                 37.52
# 4                      21.67                24.89                 26.35
#
#    taxa_atraso_2_fundamental  taxa_atraso_2_medio  taxa_freq_bruta_basico  \
# 0                      39.33                30.11                   62.66
# 1                      19.47                 3.21                   85.50
# 2                      17.82                 7.79                   90.45
# 3                      32.82                10.45                   69.79
# 4                      19.96                20.22                   65.70
#
#    taxa_freq_bruta_fundamental  taxa_freq_bruta_medio  taxa_freq_bruta_pre  \
# 0                        76.98                  10.28                 8.69
# 1                        99.90                  40.47                 9.63
# 2                       107.69                  45.99                35.40
# 3                        82.18                  25.02                17.94
# 4                        76.08                  34.92                20.81
#
#    taxa_freq_bruta_superior  taxa_freq_liquida_basico  \
# 0                      0.28                     57.69
# 1                      5.19                     76.88
# 2                     21.23                     85.25
# 3                      2.09                     62.78
# 4                      6.57                     55.27
#
#    taxa_freq_liquida_fundamental  taxa_freq_liquida_medio  \
# 0                          65.24                     3.60
# 1                          85.59                    18.01
# 2                          92.88                    34.60
# 3                          69.19                    11.63
# 4                          61.64                    13.88
#
#    taxa_freq_liquida_pre  taxa_freq_liquida_superior  taxa_freq_0_3  \
# 0                   8.69                        0.28            NaN
# 1                   9.63                        2.22           0.65
# 2                  34.15                       10.50           4.89
# 3                  17.94                        0.71            NaN
# 4                  18.93                        2.03           2.60
#
#    taxa_freq_11_14  taxa_freq_15_17  taxa_freq_18_24  taxa_freq_25_29  \
# 0            66.19            31.22             8.93             6.10
# 1            81.14            51.40            16.15             7.22
# 2            95.55            79.60            22.78             9.28
# 3            73.34            41.92            13.56             4.15
# 4            91.92            63.14            21.23            11.43
#
#    taxa_freq_4_5  taxa_freq_4_6  taxa_freq_5_6  taxa_freq_6  taxa_freq_6_14  \
# 0            NaN            NaN          17.29        25.00           65.42
# 1          16.14          27.51          40.74        58.64           86.78
# 2          39.18          54.07          70.79        81.62           95.68
# 3            NaN            NaN          28.59        37.29           70.03
# 4          23.04          36.48          47.73        61.94           89.44
#
#    taxa_freq_6_17  taxa_freq_fundamental_15_17  taxa_freq_fundamental_18_24  \
# 0           58.08                        26.48                         4.16
# 1           78.21                        30.52                         3.46
# 2           91.19                        29.58                         1.61
# 3           63.94                        26.95                         6.13
# 4           82.81                        21.79                         4.15
#
#    taxa_freq_fundamental_4_5  taxa_freq_medio_18_24  taxa_freq_medio_6_14  \
# 0                        NaN                   2.01                  0.00
# 1                       5.58                   7.70                  0.35
# 2                       5.03                   4.73                  0.54
# 3                        NaN                   4.61                  0.28
# 4                       2.41                   6.62                  0.24
#
#    taxa_freq_superior_15_17  taxa_fundamental_11_13  taxa_fundamental_12_14  \
# 0                      0.00                   17.32                   22.77
# 1                      0.00                   44.96                   51.27
# 2                      2.73                   85.65                   87.98
# 3                      0.38                   32.53                   41.93
# 4                      0.73                   40.53                   50.02
#
#    taxa_fundamental_15_17  taxa_fundamental_16_18  taxa_fundamental_18_24  \
# 0                    5.84                    7.09                   12.74
# 1                   27.23                   35.23                   32.77
# 2                   54.51                   63.55                   67.60
# 3                   13.67                   17.45                   22.30
# 4                   38.76                   42.36                   43.90
#
#    taxa_fundamental_18_mais  taxa_fundamental_25_mais  taxa_medio_18_20  \
# 0                     11.65                     11.21              3.21
# 1                     19.52                     15.39              8.43
# 2                     36.80                     29.39             40.46
# 3                     19.98                     19.08              4.67
# 4                     31.36                     27.46             16.28
#
#    taxa_medio_18_24  taxa_medio_18_mais  taxa_medio_19_21  taxa_medio_25_mais  \
# 0              4.31                4.74              3.91                4.91
# 1             14.84                9.41             13.47                7.73
# 2             39.81               23.19             38.61               19.19
# 3              6.30               10.17              5.73               11.67
# 4             19.42               16.30             20.15               15.33
#
#    taxa_superior_25_mais  renda_pc_max_quintil_1  renda_pc_max_quintil_2  \
# 0                   0.65                   39.18                   70.52
# 1                   1.13                   86.28                  147.38
# 2                   5.51                  102.40                  224.80
# 3                   3.13                   72.08                  133.98
# 4                   3.40                  130.14                  227.74
#
#    renda_pc_max_quintil_3  renda_pc_max_quintil_4  renda_pc_max_decil_9  \
# 0                  117.53                  235.05                352.58
# 1                  261.58                  447.52                780.84
# 2                  368.90                  586.67                877.00
# 3                  214.90                  419.96                656.26
# 4                  325.35                  610.52               1046.32
#
#    indice_gini  prop_pobreza_extrema  prop_pobreza_extrema_criancas  \
# 0         0.63                 39.21                          47.11
# 1         0.58                 16.15                          23.67
# 2         0.58                 14.29                          19.01
# 3         0.57                 18.90                          25.47
# 4         0.59                  8.01                          11.46
#
#    prop_pobreza  prop_pobreza_criancas  prop_vulner_pobreza  \
# 0         65.55                  71.89                83.15
# 1         35.59                  47.74                58.46
# 2         26.04                  37.33                47.12
# 3         41.30                  52.24                65.78
# 4         21.55                  30.03                47.55
#
#    prop_vulner_pobreza_criancas  prop_renda_10_ricos  prop_renda_20_pobres  \
# 0                         87.03                52.46                  2.26
# 1                         69.78                46.94                  2.26
# 2                         62.99                44.81                  1.55
# 3                         74.41                44.91                  2.62
# 4                         59.38                48.31                  2.79
#
#    prop_renda_20_ricos  prop_renda_40_pobres  prop_renda_60_pobres  \
# 0                66.65                  7.56                 16.90
# 1                62.31                  8.78                 19.64
# 2                59.87                  8.27                 20.43
# 3                61.27                  9.12                 19.77
# 4                63.57                  9.53                 19.73
#
#    prop_renda_80_pobres  prop_renda_trabalho  razao_10_ricos_40_pobres  \
# 0                 33.35                96.53                     27.75
# 1                 37.69                89.65                     21.38
# 2                 40.13                79.37                     21.68
# 3                 38.73                94.73                     19.69
# 4                 36.43                88.94                     20.27
#
#    razao_20_ricos_40_pobres  renda_pc  renda_pc_quintil_1  renda_pc_decil_10  \
# 0                     17.63    198.46               22.46            1041.07
# 1                     14.19    371.15               42.01            1742.35
# 2                     14.45    476.99               36.89            2137.18
# 3                     13.43    319.47               41.90            1434.68
# 4                     13.34    530.87               73.96            2564.65
#
#    renda_pc_quintil_2  renda_pc_quintil_3  renda_pc_quintil_4  \
# 0               52.57               92.69              163.18
# 1              120.95              201.50              334.88
# 2              160.31              289.97              469.88
# 3              103.82              170.10              302.89
# 4              179.08              270.76              443.24
#
#    renda_pc_quintil_5  renda_pc_exc_renda_nula  renda_pc_pobreza_extrema  \
# 0              661.37                   203.52                     36.83
# 1             1156.41                   386.54                     33.41
# 2             1424.61                   512.46                     14.29
# 3              978.66                   325.53                     40.20
# 4             1687.30                   545.77                     32.83
#
#    renda_pc_pobreza  renda_pc_vulner_pobreza  indice_theil  \
# 0             61.89                    88.90          0.73
# 1             73.50                   117.83          0.59
# 2             56.64                   120.71          0.60
# 3             74.85                   116.70          0.59
# 4             78.27                   144.30          0.59
#
#    prop_trabalhadores_conta_proria  prop_empregadores  \
# 0                              NaN                NaN
# 1                            47.37               1.83
# 2                            34.73               2.83
# 3                              NaN                NaN
# 4                            30.90               4.27
#
#    prop_ocupados_agropecuaria  prop_ocupados_comercio  \
# 0                         NaN                     NaN
# 1                       55.54                    8.73
# 2                       38.56                   13.78
# 3                         NaN                     NaN
# 4                       21.60                   16.75
#
#    prop_ocupados_construcao  prop_ocupados_extracao  \
# 0                       NaN                     NaN
# 1                      2.93                    0.20
# 2                      5.31                    0.00
# 3                       NaN                     NaN
# 4                      6.49                    1.02
#
#    prop_ocupados_formalizacao  prop_ocupados_fundamental  prop_ocupados_medio  \
# 0                         NaN                        NaN                  NaN
# 1                       22.83                      22.51                11.60
# 2                       41.68                      45.49                31.05
# 3                         NaN                        NaN                  NaN
# 4                       41.42                      36.12                20.64
#
#    prop_ocupados_servicos  prop_ocupados_siup  prop_ocupados_superior  \
# 0                     NaN                 NaN                     NaN
# 1                   24.69                0.54                    1.38
# 2                   33.18                0.69                    7.72
# 3                     NaN                 NaN                     NaN
# 4                   36.35                0.46                    3.91
#
#    prop_ocupados_transformacao  prop_ocupados_renda_0  \
# 0                          NaN                    NaN
# 1                         5.25                  12.51
# 2                         3.26                   9.63
# 3                          NaN                    NaN
# 4                        12.23                   6.05
#
#    prop_ocupados_renda_1_sm  prop_ocupados_renda_2_sm  \
# 0                       NaN                       NaN
# 1                     56.22                     82.67
# 2                     36.23                     78.80
# 3                       NaN                       NaN
# 4                     38.42                     72.24
#
#    prop_ocupados_renda_3_sm  prop_ocupados_renda_5_sm  renda_media_ocupados  \
# 0                       NaN                       NaN                   NaN
# 1                     89.08                     94.44                   NaN
# 2                     88.52                     95.90                950.08
# 3                       NaN                       NaN                   NaN
# 4                     80.71                     91.30                   NaN
#
#    taxa_atividade  taxa_atividade_10_14  taxa_atividade_15_17  \
# 0             NaN                   NaN                   NaN
# 1           47.76                 25.22                 64.45
# 2           51.93                  9.08                 28.98
# 3             NaN                   NaN                   NaN
# 4           45.39                 12.53                 51.41
#
#    taxa_atividade_18_24  taxa_atividade_18_mais  taxa_atividade_25_29  \
# 0                   NaN                     NaN                   NaN
# 1                 67.66                   69.30                 73.06
# 2                 63.44                   60.43                 62.94
# 3                   NaN                     NaN                   NaN
# 4                 70.13                   68.82                 72.74
#
#    taxa_desocupacao  taxa_desocupacao_10_14  taxa_desocupacao_15_17  \
# 0               NaN                     NaN                     NaN
# 1              6.57                    9.77                   10.96
# 2              6.07                   10.51                   23.16
# 3               NaN                     NaN                     NaN
# 4              9.82                   12.55                   23.18
#
#    taxa_desocupacao_18_24  taxa_desocupacao_18_mais  taxa_desocupacao_25_29  \
# 0                     NaN                       NaN                     NaN
# 1                    8.77                      5.85                    7.90
# 2                   10.25                      5.17                    5.06
# 3                     NaN                       NaN                     NaN
# 4                   13.04                      8.53                   10.00
#
#    indice_treil_trabalho  taxa_ocupados_carteira  taxa_ocupados_setor_publico  \
# 0                    NaN                     NaN                          NaN
# 1                   0.60                   15.35                         2.46
# 2                   0.52                   25.17                         5.31
# 3                    NaN                     NaN                          NaN
# 4                   0.54                   30.70                         5.38
#
#    taxa_ocupados_sem_carteira  taxa_agua_encanada  \
# 0                         NaN               21.92
# 1                       20.48               57.13
# 2                       23.17               93.69
# 3                         NaN               53.30
# 4                       23.03               73.54
#
#    taxa_banheiro_agua_encanada  taxa_densidade_2_mais  taxa_coleta_lixo  \
# 0                        18.47                  52.80              6.82
# 1                        42.56                  37.84             70.33
# 2                        80.20                  22.58             94.05
# 3                        48.50                  54.10             78.30
# 4                        67.08                  37.55             90.61
#
#    taxa_energia_eletrica  taxa_agua_esgoto_inadequados  \
# 0                  36.80                          7.45
# 1                  70.14                         27.52
# 2                  93.98                          9.31
# 3                  73.28                          2.55
# 4                  93.43                         21.14
#
#    taxa_paredes_inadequados  taxa_criancas_dom_sem_fund  \
# 0                       NaN                         NaN
# 1                      0.00                       70.32
# 2                      7.18                       45.73
# 3                       NaN                         NaN
# 4                      0.00                       51.17
#
#    taxa_criancas_fora_escola_4_5  taxa_criancas_fora_escola_6_14  \
# 0                            NaN                           34.58
# 1                          83.86                           13.22
# 2                          60.82                            4.32
# 3                            NaN                           29.97
# 4                          76.96                           10.56
#
#    taxa_dom_sem_fund  taxa_dom_vulner_sem_fund  taxa_sem_fund_informal  \
# 0              37.10                     33.34                     NaN
# 1              62.92                     43.34                   72.51
# 2              40.27                     24.81                   54.06
# 3              33.27                     24.75                     NaN
# 4              46.03                     29.61                   55.81
#
#    taxa_mulheres_com_filho_10_14  taxa_mulheres_com_filho_15_17  \
# 0                           0.00                          14.41
# 1                           0.00                          12.58
# 2                           0.00                           6.75
# 3                           1.03                          13.25
# 4                           1.56                          11.16
#
#    taxa_mulheres_chefe_filho_15m  taxa_nest_ntrab_vulner_15_24  \
# 0                           6.14                           NaN
# 1                          10.93                         19.73
# 2                          14.51                         16.12
# 3                          13.86                           NaN
# 4                          20.33                         15.60
#
#    taxa_vulner_desloc_1_hora  taxa_dom_vulner_dep_idoso  \
# 0                        NaN                       1.57
# 1                       0.00                       1.19
# 2                       1.15                       2.20
# 3                        NaN                       1.66
# 4                       0.00                       1.60
#
#    taxa_sem_energia_eletrica  populacao_homens_0_4  populacao_homens_10_14  \
# 0                      63.20                  1684                    1584
# 1                      29.86                  1496                    1570
# 2                       6.02                   956                    1256
# 3                      26.72                  3964                    3627
# 4                       6.57                  4498                    4269
#
#    populacao_homens_15_19  populacao_homens_20_24  populacao_homens_25_29  \
# 0                    1413                    1212                    1109
# 1                    1522                    1292                    1144
# 2                    1362                    1105                    1053
# 3                    3134                    2947                    2823
# 4                    4072                    3571                    3247
#
#    populacao_homens_30_34  populacao_homens_35_39  populacao_homens_40_44  \
# 0                     923                     711                     521
# 1                    1081                    1026                     852
# 2                     951                     878                     913
# 3                    2289                    1862                    1393
# 4                    3165                    2771                    2248
#
#    populacao_homens_45_49  populacao_homens_50_54  populacao_homens_55_59  \
# 0                     464                     395                     327
# 1                     597                     428                     366
# 2                     846                     631                     489
# 3                    1070                     836                     672
# 4                    1659                    1228                     919
#
#    populacao_homens_5_9  populacao_homens_60_64  populacao_homens_65_69  \
# 0                  1580                     232                     132
# 1                  1677                     345                     249
# 2                  1073                     351                     301
# 3                  3802                     473                     321
# 4                  4353                     751                     551
#
#    populacao_homens_70_74  populacao_homens_75_79  populacao_homens  \
# 0                      54                      38             12401
# 1                     155                      74             13924
# 2                     239                     154             12656
# 3                     150                      77             29495
# 4                     367                     184             37995
#
#    populacao_homens_80_mais  populacao_mulheres_0_4  populacao_mulheres_10_14  \
# 0                        25                    1634                      1479
# 1                        50                    1372                      1532
# 2                        98                     952                      1145
# 3                        59                    3819                      3480
# 4                       142                    4177                      4206
#
#    populacao_mulheres_15_19  populacao_mulheres_20_24  \
# 0                      1414                      1089
# 1                      1472                      1216
# 2                      1226                      1095
# 3                      3184                      3003
# 4                      4117                      3774
#
#    populacao_mulheres_25_29  populacao_mulheres_30_34  \
# 0                       980                       766
# 1                      1118                       977
# 2                      1039                       916
# 3                      2610                      2039
# 4                      3479                      3132
#
#    populacao_mulheres_35_39  populacao_mulheres_40_44  \
# 0                       578                       440
# 1                       925                       648
# 2                       917                       802
# 3                      1654                      1189
# 4                      2517                      1980
#
#    populacao_mulheres_45_49  populacao_mulheres_50_54  \
# 0                       364                       288
# 1                       476                       356
# 2                       720                       515
# 3                       857                       624
# 4                      1512                      1086
#
#    populacao_mulheres_55_59  populacao_mulheres_5_9  populacao_mulheres_60_64  \
# 0                       219                    1587                       132
# 1                       324                    1580                       251
# 2                       431                    1034                       311
# 3                       468                    3661                       303
# 4                       804                    4221                       569
#
#    populacao_mulheres_65_69  populacao_mulheres_70_74  \
# 0                        75                        47
# 1                       170                       101
# 2                       264                       177
# 3                       202                       121
# 4                       426                       246
#
#    populacao_mulheres_75_79  populacao_mulheres_80_mais  populacao_mulheres  \
# 0                        33                          25               11146
# 1                        45                          46               12609
# 2                       119                          73               11736
# 3                        61                          47               27318
# 4                       146                         116               36508
#
#    populacao_1_menos  populacao_11_14  populacao_11_13  populacao_12_14  \
# 0                700             2387             1816             1771
# 1                515             2453             1899             1780
# 2                369             1883             1397             1434
# 3               1614             5636             4279             4131
# 4               1784             6771             5112             5027
#
#    populacao_1_3  populacao_15_mais  populacao_15_17  populacao_15_24  \
# 0           1986              14000             1742             5128
# 1           1747              17300             1848             5502
# 2           1140              17976             1577             4788
# 3           4624              34461             3811            12268
# 4           5075              48771             4922            15534
#
#    populacao_16_18  populacao_18_mais  populacao_18_20  populacao_18_24  \
# 0             1709              12258             1571             3386
# 1             1793              15458             1699             3654
# 2             1536              16399             1497             3211
# 3             3818              30650             3699             8458
# 4             5040              43857             4812            10612
#
#    populacao_19_21  populacao_25_mais  populacao_4  populacao_5  populacao_6  \
# 0             1467               8872          633          604          634
# 1             1588              11802          606          655          634
# 2             1433              13188          399          429          413
# 3             3663              22193         1546         1535         1449
# 4             4550              33238         1816         1840         1720
#
#    populacao_6_10  populacao_6_17  populacao_65_mais  populacao  \
# 0            3238            7367                428      23546
# 1            3251            7552                890      26533
# 2            2196            5170               1425      24392
# 3            7399           16845               1035      56812
# 4            8438           20131               2178      74503
#
#    populacao_urbana  populacao_rural  populacao_dom_pp  \
# 0              9379            14167             23417
# 1             12341            14192             25920
# 2             13970            10422             24097
# 3             45283            11529             56061
# 4             55118            19385             71789
#
#    populacao_dom_pp_exc_renda_nula      pea  pea_10_14  pea_15_17  \
# 0                            22835      NaN        NaN        NaN
# 1                            24888  12670.0      767.0     1179.0
# 2                            22429  10611.0      218.0      464.0
# 3                            55018      NaN        NaN        NaN
# 4                            69829  33705.0     1038.0     2668.0
#
#    pea_18_mais      pia  pia_10_14  pia_15_17  pia_18_mais  \
# 0          NaN      NaN        NaN        NaN          NaN
# 1      10724.0  20346.0     3040.0     1830.0      15476.0
# 2       9928.0  20434.0     2401.0     1602.0      16431.0
# 3          NaN      NaN        NaN        NaN          NaN
# 4      29999.0  57064.0     8285.0     5190.0      43589.0
#
#    indice_escolaridade  indice_frequencia_escolar   idhm  idhm_e  idhm_l  \
# 0                0.117                      0.109  0.329   0.112   0.617
# 1                0.195                      0.303  0.483   0.262   0.698
# 2                0.368                      0.629  0.641   0.526   0.763
# 3                0.200                      0.199  0.432   0.199   0.684
# 4                0.314                      0.358  0.556   0.343   0.742
#
#    idhm_r
# 0   0.516
# 1   0.617
# 2   0.657
# 3   0.593
# 4   0.674

# %% [markdown]
# * Selecionando indicadores do ano de 2010

# %%
df = df[df['ano']==2010]

# %% [markdown]
# * Transformando a variável fecundidade_total em categorica

# %%
df['fecundidade_total'].isna().sum() #inicialmente verificando se há algum nulo
# Out:
# 0

# %%
df['class_fecundidade_total'] = pd.qcut(df['fecundidade_total'],4) #criando 04 categorias, com base nos quantis

# %%
df['class_fecundidade_total'].value_counts()
# Out:
# (1.209, 1.85]    1433
# (2.13, 2.46]     1412
# (2.46, 4.89]     1363
# (1.85, 2.13]     1357
# Name: class_fecundidade_total, dtype: int64

# %% [markdown]
# * Selecionando a variável de expectativa de vida como variável dependente
# * Selecionando a) expectativa_anos_estudo; b) indice_gini; c) prop_trabalhadores_conta_propria; d) indice_frequencia_escolar e e) fecundidade total (categorica) como variáveis independentes

# %%
df = df[['expectativa_vida','expectativa_anos_estudo','indice_gini', 'prop_trabalhadores_conta_proria','indice_frequencia_escolar','class_fecundidade_total']]
df_dep = df[['expectativa_vida']]
df_indep = df[['expectativa_anos_estudo','indice_gini', 'prop_trabalhadores_conta_proria','indice_frequencia_escolar','class_fecundidade_total']]

# %% [markdown]
# ### Análises Iniciais

# %% [markdown]
# * Calculando a correlação de pearson entre as variáveis quanti, indica correlação linear entre as variáveis

# %%
df.corr(method = 'pearson')
# Out:
#                                  expectativa_vida  expectativa_anos_estudo  \
# expectativa_vida                         1.000000                 0.440502
# expectativa_anos_estudo                  0.440502                 1.000000
# indice_gini                             -0.379577                -0.395585
# prop_trabalhadores_conta_proria          0.027054                 0.051224
# indice_frequencia_escolar                0.640819                 0.785163
#
#                                  indice_gini  prop_trabalhadores_conta_proria  \
# expectativa_vida                   -0.379577                         0.027054
# expectativa_anos_estudo            -0.395585                         0.051224
# indice_gini                         1.000000                         0.024256
# prop_trabalhadores_conta_proria     0.024256                         1.000000
# indice_frequencia_escolar          -0.529805                         0.018951
#
#                                  indice_frequencia_escolar
# expectativa_vida                                  0.640819
# expectativa_anos_estudo                           0.785163
# indice_gini                                      -0.529805
# prop_trabalhadores_conta_proria                   0.018951
# indice_frequencia_escolar                         1.000000

# %% [markdown]
# * Calculando a correlação de spearman entre as variáveis quanti, indica correlação monotônica entre as variáveis

# %%
df.corr(method = 'spearman')
# Out:
#                                  expectativa_vida  expectativa_anos_estudo  \
# expectativa_vida                         1.000000                 0.468071
# expectativa_anos_estudo                  0.468071                 1.000000
# indice_gini                             -0.406924                -0.366153
# prop_trabalhadores_conta_proria         -0.024963                 0.005804
# indice_frequencia_escolar                0.673751                 0.767891
#
#                                  indice_gini  prop_trabalhadores_conta_proria  \
# expectativa_vida                   -0.406924                        -0.024963
# expectativa_anos_estudo            -0.366153                         0.005804
# indice_gini                         1.000000                         0.117791
# prop_trabalhadores_conta_proria     0.117791                         1.000000
# indice_frequencia_escolar          -0.517690                        -0.029598
#
#                                  indice_frequencia_escolar
# expectativa_vida                                  0.673751
# expectativa_anos_estudo                           0.767891
# indice_gini                                      -0.517690
# prop_trabalhadores_conta_proria                  -0.029598
# indice_frequencia_escolar                         1.000000

# %% [markdown]
# * Verificando o comportamento da expectativa de vida conforme as categorias de fecundidade total

# %%
sns.boxplot(x="class_fecundidade_total", y="expectativa_vida", data=df, palette="Set1")
# Out:
# <AxesSubplot:xlabel='class_fecundidade_total', ylabel='expectativa_vida'>

# %% [markdown]
# ### Modelo inicial de regressão

# %% [markdown]
# * Transformando a variavel categorica em dummy

# %%
df_indep['class_fecundidade_total'].value_counts()
# Out:
# (1.209, 1.85]    1433
# (2.13, 2.46]     1412
# (2.46, 4.89]     1363
# (1.85, 2.13]     1357
# Name: class_fecundidade_total, dtype: int64

# %%
df_indep = pd.get_dummies(df_indep, prefix = 'Classe Fecundidade', prefix_sep = "_", columns = ['class_fecundidade_total'])

# %%
df_indep.head()
# Out:
#     expectativa_anos_estudo  indice_gini  prop_trabalhadores_conta_proria  \
# 2                      8.67         0.58                            34.73
# 5                      9.18         0.53                            27.66
# 8                     10.09         0.51                            32.98
# 11                     9.74         0.57                            24.97
# 14                    10.22         0.50                            28.46
#
#     indice_frequencia_escolar  Classe Fecundidade_(1.209, 1.85]  \
# 2                       0.629                                 0
# 5                       0.648                                 0
# 8                       0.700                                 0
# 11                      0.698                                 0
# 14                      0.712                                 0
#
#     Classe Fecundidade_(1.85, 2.13]  Classe Fecundidade_(2.13, 2.46]  \
# 2                                 0                                1
# 5                                 1                                0
# 8                                 0                                1
# 11                                1                                0
# 14                                1                                0
#
#     Classe Fecundidade_(2.46, 4.89]
# 2                                 0
# 5                                 0
# 8                                 0
# 11                                0
# 14                                0

# %% [markdown]
# * Modelo com todas as variáveis

# %%
df_indep = sm.add_constant(df_indep)

# %%
model = sm.OLS(df_dep, df_indep).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       expectativa_vida   R-squared:                       0.455
# Model:                            OLS   Adj. R-squared:                  0.454
# Method:                 Least Squares   F-statistic:                     663.2
# Date:                Fri, 09 Jul 2021   Prob (F-statistic):               0.00
# Time:                        23:09:05   Log-Likelihood:                -11694.
# No. Observations:                5565   AIC:                         2.340e+04
# Df Residuals:                    5557   BIC:                         2.346e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# const                               51.9877      0.337    154.469      0.000      51.328      52.648
# expectativa_anos_estudo             -0.3212      0.039     -8.161      0.000      -0.398      -0.244
# indice_gini                         -0.6975      0.482     -1.447      0.148      -1.643       0.248
# prop_trabalhadores_conta_proria      0.0030      0.003      1.102      0.270      -0.002       0.008
# indice_frequencia_escolar           17.0683      0.523     32.658      0.000      16.044      18.093
# Classe Fecundidade_(1.209, 1.85]    13.7875      0.104    132.338      0.000      13.583      13.992
# Classe Fecundidade_(1.85, 2.13]     13.2411      0.098    135.633      0.000      13.050      13.432
# Classe Fecundidade_(2.13, 2.46]     12.7667      0.094    136.272      0.000      12.583      12.950
# Classe Fecundidade_(2.46, 4.89]     12.1924      0.096    127.385      0.000      12.005      12.380
# ==============================================================================
# Omnibus:                       37.366   Durbin-Watson:                   1.301
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               37.945
# Skew:                          -0.199   Prob(JB):                     5.76e-09
# Kurtosis:                       3.075   Cond. No.                     2.79e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 5.61e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %% [markdown]
# #### Verificando os pressupostos

# %% [markdown]
# * Normalidade dos Resíduos

# %%
previsao = model.predict()

# %%
residuos = previsao - df_dep['expectativa_vida']

# %%
plt.hist(residuos, color='blue', bins=21)
plt.title('Resíduos')
plt.show()

# %%
from scipy import stats
statistic ,pvalue = stats.shapiro(residuos)
print(statistic)
print(pvalue)
# Out:
# 0.9968830943107605
# 2.214972871783516e-09
# C:\Users\gcabr\Anaconda3\lib\site-packages\scipy\stats\morestats.py:1681: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")

# %% [markdown]
# * Multicolinearidade

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
def vif(X):
    vif = pd.DataFrame()
    vif["variables"] = X.columns
    vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
    return(vif)

# %%
df_indep = df[['expectativa_anos_estudo','indice_gini', 'prop_trabalhadores_conta_proria','indice_frequencia_escolar','class_fecundidade_total']]
df_indep = pd.get_dummies(df_indep, prefix = 'Classe Fecundidade', prefix_sep = "_", columns = ['class_fecundidade_total'])

# %%
vif(df_indep.iloc[:,:-1])
# Out:
#                           variables         VIF
# 0           expectativa_anos_estudo  184.285069
# 1                       indice_gini   28.655081
# 2   prop_trabalhadores_conta_proria    7.366521
# 3         indice_frequencia_escolar  158.531156
# 4  Classe Fecundidade_(1.209, 1.85]    3.060501
# 5   Classe Fecundidade_(1.85, 2.13]    2.494798
# 6   Classe Fecundidade_(2.13, 2.46]    2.266789

# %%
del df_indep['expectativa_anos_estudo']

# %%
vif(df_indep.iloc[:,:-1])
# Out:
#                           variables        VIF
# 0                       indice_gini  23.367691
# 1   prop_trabalhadores_conta_proria   7.290990
# 2         indice_frequencia_escolar  33.394471
# 3  Classe Fecundidade_(1.209, 1.85]   3.026440
# 4   Classe Fecundidade_(1.85, 2.13]   2.484915
# 5   Classe Fecundidade_(2.13, 2.46]   2.266771

# %% [markdown]
# * Heterocedasticidade

# %%
from statsmodels.compat import lzip
import statsmodels.stats.api as sms

# %%
names = ['Lagrange multiplier statistic', 'p-value',
        'f-value', 'f p-value']
test = sms.het_breuschpagan(model.resid, model.model.exog)

# %%
lzip(names, test)
# Out:
# [('Lagrange multiplier statistic', 192.79297216411007),
#  ('p-value', 2.1045289281244785e-37),
#  ('f-value', 28.489236779616657),
#  ('f p-value', 7.998861970075331e-39)]

# %% [markdown]
# ### Seleção das Variáveis Regressora - Método Backward

# %%
df_indep = df[['expectativa_anos_estudo','indice_gini', 'prop_trabalhadores_conta_proria','indice_frequencia_escolar','class_fecundidade_total']]
df_indep = pd.get_dummies(df_indep, prefix = 'Classe Fecundidade', prefix_sep = "_", columns = ['class_fecundidade_total'])

# %%
df_indep = sm.add_constant(df_indep)
model = sm.OLS(df_dep, df_indep).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       expectativa_vida   R-squared:                       0.455
# Model:                            OLS   Adj. R-squared:                  0.454
# Method:                 Least Squares   F-statistic:                     663.2
# Date:                Fri, 09 Jul 2021   Prob (F-statistic):               0.00
# Time:                        23:09:54   Log-Likelihood:                -11694.
# No. Observations:                5565   AIC:                         2.340e+04
# Df Residuals:                    5557   BIC:                         2.346e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# const                               51.9877      0.337    154.469      0.000      51.328      52.648
# expectativa_anos_estudo             -0.3212      0.039     -8.161      0.000      -0.398      -0.244
# indice_gini                         -0.6975      0.482     -1.447      0.148      -1.643       0.248
# prop_trabalhadores_conta_proria      0.0030      0.003      1.102      0.270      -0.002       0.008
# indice_frequencia_escolar           17.0683      0.523     32.658      0.000      16.044      18.093
# Classe Fecundidade_(1.209, 1.85]    13.7875      0.104    132.338      0.000      13.583      13.992
# Classe Fecundidade_(1.85, 2.13]     13.2411      0.098    135.633      0.000      13.050      13.432
# Classe Fecundidade_(2.13, 2.46]     12.7667      0.094    136.272      0.000      12.583      12.950
# Classe Fecundidade_(2.46, 4.89]     12.1924      0.096    127.385      0.000      12.005      12.380
# ==============================================================================
# Omnibus:                       37.366   Durbin-Watson:                   1.301
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               37.945
# Skew:                          -0.199   Prob(JB):                     5.76e-09
# Kurtosis:                       3.075   Cond. No.                     2.79e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 5.61e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
del df_indep['prop_trabalhadores_conta_proria']

# %%
model = sm.OLS(df_dep, df_indep).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       expectativa_vida   R-squared:                       0.455
# Model:                            OLS   Adj. R-squared:                  0.454
# Method:                 Least Squares   F-statistic:                     773.5
# Date:                Fri, 09 Jul 2021   Prob (F-statistic):               0.00
# Time:                        23:09:54   Log-Likelihood:                -11694.
# No. Observations:                5565   AIC:                         2.340e+04
# Df Residuals:                    5558   BIC:                         2.345e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# const                               52.0289      0.334    155.550      0.000      51.373      52.685
# expectativa_anos_estudo             -0.3184      0.039     -8.107      0.000      -0.395      -0.241
# indice_gini                         -0.6765      0.482     -1.404      0.160      -1.621       0.268
# indice_frequencia_escolar           17.0466      0.522     32.639      0.000      16.023      18.070
# Classe Fecundidade_(1.209, 1.85]    13.8041      0.103    133.897      0.000      13.602      14.006
# Classe Fecundidade_(1.85, 2.13]     13.2489      0.097    136.072      0.000      13.058      13.440
# Classe Fecundidade_(2.13, 2.46]     12.7724      0.094    136.531      0.000      12.589      12.956
# Classe Fecundidade_(2.46, 4.89]     12.2035      0.095    128.218      0.000      12.017      12.390
# ==============================================================================
# Omnibus:                       37.599   Durbin-Watson:                   1.295
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               38.190
# Skew:                          -0.199   Prob(JB):                     5.09e-09
# Kurtosis:                       3.079   Cond. No.                     8.63e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 6.92e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
del df_indep['indice_gini']

# %%
model = sm.OLS(df_dep, df_indep).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       expectativa_vida   R-squared:                       0.455
# Model:                            OLS   Adj. R-squared:                  0.454
# Method:                 Least Squares   F-statistic:                     927.7
# Date:                Fri, 09 Jul 2021   Prob (F-statistic):               0.00
# Time:                        23:09:57   Log-Likelihood:                -11695.
# No. Observations:                5565   AIC:                         2.340e+04
# Df Residuals:                    5559   BIC:                         2.344e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# const                               51.6576      0.205    252.147      0.000      51.256      52.059
# expectativa_anos_estudo             -0.3197      0.039     -8.140      0.000      -0.397      -0.243
# indice_frequencia_escolar           17.2582      0.500     34.509      0.000      16.278      18.239
# Classe Fecundidade_(1.209, 1.85]    13.7193      0.084    164.214      0.000      13.556      13.883
# Classe Fecundidade_(1.85, 2.13]     13.1602      0.074    177.543      0.000      13.015      13.306
# Classe Fecundidade_(2.13, 2.46]     12.6809      0.067    188.848      0.000      12.549      12.813
# Classe Fecundidade_(2.46, 4.89]     12.0972      0.058    209.740      0.000      11.984      12.210
# ==============================================================================
# Omnibus:                       37.933   Durbin-Watson:                   1.292
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               38.547
# Skew:                          -0.199   Prob(JB):                     4.26e-09
# Kurtosis:                       3.086   Cond. No.                     1.70e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.79e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %% [markdown]
# ##### Verificando os pressupostos

# %%
from scipy import stats
statistic ,pvalue = stats.shapiro(model.resid)
print(statistic)
print(pvalue)
# Out:
# 0.9968352913856506
# 1.7382875139304588e-09
# C:\Users\gcabr\Anaconda3\lib\site-packages\scipy\stats\morestats.py:1681: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")

# %%
vif(df_indep.iloc[:,1:])
# Out:
#                           variables        VIF
# 0           expectativa_anos_estudo   2.639831
# 1         indice_frequencia_escolar   3.279286
# 2  Classe Fecundidade_(1.209, 1.85]  28.136444
# 3   Classe Fecundidade_(1.85, 2.13]  24.586162
# 4   Classe Fecundidade_(2.13, 2.46]  23.967254
# 5   Classe Fecundidade_(2.46, 4.89]  20.006811

# %%
names = ['Lagrange multiplier statistic', 'p-value',
        'f-value', 'f p-value']
test = sms.het_breuschpagan(model.resid, model.model.exog)

# %%
lzip(names, test)
# Out:
# [('Lagrange multiplier statistic', 193.53673481216765),
#  ('p-value', 4.5024010359622124e-39),
#  ('f-value', 40.05875701667736),
#  ('f p-value', 1.3583551903976357e-40)]

# %% [markdown]
# ### Análise de Resíduos

# %%
previsao = model.predict()
residuos = previsao - df_dep['expectativa_vida']

# %%
sns.kdeplot(x = previsao, y = residuos, cmap="Blues", shade=True)
plt.axhline(y=0, color='r', linestyle='--')
plt.show()

# %%
sns.kdeplot(x = df_indep['expectativa_anos_estudo'], y = residuos, cmap="Blues", shade=True)
plt.axhline(y=0, color='r', linestyle='--')
plt.show()

# %%
sns.kdeplot(x = df_indep['indice_frequencia_escolar'], y = residuos, cmap="Blues", shade=True)
plt.axhline(y=0, color='r', linestyle='--')
plt.show()

# %%
sns.stripplot(x = df_indep['Classe Fecundidade_(1.209, 1.85]'], y = residuos, jitter=0.1, size=1.3)
plt.show()

# %%
sns.stripplot(x = df_indep['Classe Fecundidade_(1.85, 2.13]'], y = residuos, jitter=0.1, size=1.3)
plt.show()

# %%
sns.stripplot(x = df_indep['Classe Fecundidade_(2.13, 2.46]'], y = residuos, jitter=0.1, size=1.3)
plt.show()

# %%
sns.stripplot(x = df_indep['Classe Fecundidade_(2.46, 4.89]'], y = residuos, jitter=0.1, size=1.3)
plt.show()

# %%
influence = model.get_influence()
cooks = influence.cooks_distance

# %%
plt.plot((df_indep.reset_index()).index, cooks[0], linestyle = 'none' ,marker='o',markersize=1.5)
plt.xlabel('Observações')
plt.ylabel('Distância de Cook')
plt.show()
